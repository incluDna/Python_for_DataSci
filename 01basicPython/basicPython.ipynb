# %% [markdown]
# <a href="https://colab.research.google.com/github/incluDna/Python_for_DataSci/blob/main/01basicPython/basicPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world

# %%
temp = int(input())
if temp >= 40:
  a=2
  print('yes')
else:
  print('no')
# Out:
# 35
# no

# %%
temp = int(input())
if temp >= 40:
  a=2
  print('yes, you have enough money to\
 buy it')
else:
  print('no')
# Out:
# 40
# yes, you have enough money to buy it

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-217463bd-2186-4714-b25b-19e19c3b74c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-217463bd-2186-4714-b25b-19e19c3b74c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# format in this file(dataset_41_01.csv) is already cp874, so in next step, we don't have to encoding.

# %%
f=open('dataset_41_01.csv')
for line in f:
  print(line)
f.close()
# Out:
# ﻿province,year,Source of income,value,unit,soure
#
# ชัยภูมิ,2566,ค่าจ้างและเงินเดือน,"6,076.32",บาท,สำนักงานสถิติจังหวัดชัยภูมิ
#
# ชัยภูมิ,2566,กำไรสุทธิจากการทำธุรกิจ,"3,080.34",บาท,สำนักงานสถิติจังหวัดชัยภูมิ
#
# ชัยภูมิ,2566,กำไรสุทธิจากการทำเกษตร,"2,287.84",บาท,สำนักงานสถิติจังหวัดชัยภูมิ
#
# ชัยภูมิ,2566,เงินได้รับเป็นการช่วยเหลือ,"6,432.14",บาท,สำนักงานสถิติจังหวัดชัยภูมิ
#
# ชัยภูมิ,2566,รายได้จากทรัพย์สิน,227.99,บาท,สำนักงานสถิติจังหวัดชัยภูมิ
#
# ชัยภูมิ,2566,รายได้ที่ไม่เป็นตัวเงิน,"4,339.89",บาท,สำนักงานสถิติจังหวัดชัยภูมิ
#
# ชัยภูมิ,2566,รายรับที่เป็นตัวเงินอื่น ๆ,333.49,บาท,สำนักงานสถิติจังหวัดชัยภูมิ
#
# ชัยภูมิ,2564,ค่าจ้างและเงินเดือน,"5,409.20",บาท,สำนักงานสถิติจังหวัดชัยภูมิ
#
# ชัยภูมิ,2564,กำไรสุทธิจากการทำธุรกิจ,"3,393.58",บาท,สำนักงานสถิติจังหวัดชัยภูมิ
#
# ชัยภูมิ,2564,กำไรสุทธิจากการทำเกษตร,"2,520.34",บาท,สำนักงานสถิติจังหวัดชัยภูมิ
#
# ชัยภูมิ,2564,เงินได้รับเป็นการช่วยเหลือ,"4,830.30",บาท,สำนักงานสถิติจังหวัดชัยภูมิ
#
# ...
